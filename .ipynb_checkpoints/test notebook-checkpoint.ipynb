# %%
import torch
import pandas
import PIL

from PIL import Image

# %%
hi = True
if ((hi==True) & (5==5)):
    print('bye')
# Out:
# bye

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
model.conf = 0.25 # NMS confidence threshold
model.max_det = 100 # maximum number of detections per image
# Out:
# Using cache found in /home/astutt/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2022-12-4 Python-3.10.8 torch-1.13.0 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
im = 'test_images/test.png'
results = model(im)

# %%
print(results)
# Out:
# image 1/1: 490x744 1 banana, 8 apples, 6 oranges
# Speed: 22.3ms pre-process, 78.9ms inference, 1.1ms NMS per image at shape (1, 3, 448, 640)

# %%
results
# Out:
# YOLOv5 <class 'models.common.Detections'> instance
# image 1/1: 490x744 1 banana, 8 apples, 6 oranges
# Speed: 16.4ms pre-process, 70.7ms inference, 0.9ms NMS per image at shape (1, 3, 448, 640)

# %%
image = results.save()
result_image = Image.open(image)
# Out:
# Saved 1 image to runs/detect/exp
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/anaconda3/envs/24769-deploy/lib/python3.10/site-packages/PIL/Image.py:3096, in open(fp, mode, formats)
#    3095 try:
# -> 3096     fp.seek(0)
#    3097 except (AttributeError, io.UnsupportedOperation):
#
# AttributeError: 'NoneType' object has no attribute 'seek'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In [30], line 2
#       1 image = results.save()
# ----> 2 result_image = Image.open(image)
#
# File ~/anaconda3/envs/24769-deploy/lib/python3.10/site-packages/PIL/Image.py:3098, in open(fp, mode, formats)
#    3096     fp.seek(0)
#    3097 except (AttributeError, io.UnsupportedOperation):
# -> 3098     fp = io.BytesIO(fp.read())
#    3099     exclusive_fp = True
#    3101 prefix = fp.read(16)
#
# AttributeError: 'NoneType' object has no attribute 'read'

# %%
#results.show()
Image.open(runs/detect/exp)
# Out:
# <PIL.Image.Image image mode=RGB size=744x490>
# Saved 1 image to runs/detect/exp
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/anaconda3/envs/24769-deploy/lib/python3.10/site-packages/PIL/Image.py:3096, in open(fp, mode, formats)
#    3095 try:
# -> 3096     fp.seek(0)
#    3097 except (AttributeError, io.UnsupportedOperation):
#
# AttributeError: 'NoneType' object has no attribute 'seek'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In [25], line 2
#       1 results.show()
# ----> 2 Image.open(results.save())
#
# File ~/anaconda3/envs/24769-deploy/lib/python3.10/site-packages/PIL/Image.py:3098, in open(fp, mode, formats)
#    3096     fp.seek(0)
#    3097 except (AttributeError, io.UnsupportedOperation):
# -> 3098     fp = io.BytesIO(fp.read())
#    3099     exclusive_fp = True
#    3101 prefix = fp.read(16)
#
# AttributeError: 'NoneType' object has no attribute 'read'

# %%
results.xyxy[0]
# Out:
# tensor([[4.99515e+02, 3.34382e+02, 7.36735e+02, 4.90000e+02, 5.81463e-01, 4.70000e+01],
#         [4.84604e+02, 7.19716e+01, 7.11995e+02, 2.06823e+02, 5.56984e-01, 4.70000e+01],
#         [2.30579e+02, 2.85282e+02, 5.29094e+02, 4.77940e+02, 4.97846e-01, 4.70000e+01],
#         [0.00000e+00, 2.29143e+02, 1.61047e+02, 3.56622e+02, 4.54605e-01, 4.90000e+01],
#         [6.20979e+01, 1.01596e+02, 1.25468e+02, 1.47164e+02, 4.36517e-01, 4.60000e+01],
#         [2.85862e+02, 3.14458e+02, 3.57565e+02, 3.84145e+02, 4.12415e-01, 4.70000e+01],
#         [3.66739e+02, 1.95258e+02, 6.58348e+02, 3.41109e+02, 3.79763e-01, 4.70000e+01],
#         [2.20547e+02, 1.82831e+02, 3.97776e+02, 2.84088e+02, 3.44613e-01, 4.90000e+01],
#         [3.67549e+02, 2.90593e+02, 4.37197e+02, 3.77939e+02, 3.27349e-01, 4.70000e+01],
#         [4.37859e+02, 2.95278e+02, 5.01831e+02, 3.65779e+02, 3.00612e-01, 4.70000e+01],
#         [1.16397e+02, 2.49876e+02, 1.61542e+02, 2.92098e+02, 2.99643e-01, 4.90000e+01],
#         [3.12077e+02, 2.34183e+02, 3.60175e+02, 2.84383e+02, 2.91335e-01, 4.90000e+01],
#         [3.58796e+01, 3.03440e+02, 8.10276e+01, 3.47155e+02, 2.81446e-01, 4.90000e+01],
#         [6.50359e+00, 3.48583e+02, 5.77491e+01, 3.91091e+02, 2.77153e-01, 4.90000e+01],
#         [6.07990e+02, 2.44307e+02, 7.42274e+02, 3.90757e+02, 2.73160e-01, 4.70000e+01]])

# %%
table = results.pandas().xyxy[0]
result_class = table['name']
result_class[7]
# Out:
# 'orange'
